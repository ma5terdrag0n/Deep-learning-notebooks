# %%
# Testing if GPU is being used or not
import torch
print(torch.cuda.current_device()) # Should print 0 for GPU
print(torch.cuda.device(0)) # Should print the cuda device name
print(torch.cuda.device_count()) # Should print 1
print(torch.cuda.get_device_name(0)) # Graphic card name
print(torch.cuda.is_available()) # Should print true
# Out:
# 0
# ...
# 1
# GeForce GTX 1050 Ti
# True

# %%
from fastai.vision import *

# %%
folder = 'apple'
file = 'apple'
path = Path('data/fruits')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(file, dest, max_pics=200)

# %%
folder = 'ornage'
file = 'orange'
path = Path('data/fruits')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(file, dest, max_pics=200)

# %%
folder = 'banana'
file = 'banana'
path = Path('data/fruits')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)
download_images(file, dest, max_pics=200)

# %%
classes = ['apple', 'orange', 'banana']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# apple
# orange
# banana

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['apple', 'banana', 'orange']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
print(data)
# Out:
# ImageDataBunch;
#
# Train: LabelList (256 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# apple,apple,apple,apple,apple
# Path: data\fruits;
#
# Valid: LabelList (64 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# banana,banana,apple,apple,apple
# Path: data\fruits;
#
# Test: None

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.609789</td>
#       <td>0.089763</td>
#       <td>0.015625</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.923119</td>
#       <td>0.011780</td>
#       <td>0.000000</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.646483</td>
#       <td>0.004640</td>
#       <td>0.000000</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.488966</td>
#       <td>0.005515</td>
#       <td>0.000000</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.051160</td>
#       <td>0.044560</td>
#       <td>0.031250</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.046105</td>
#       <td>0.031987</td>
#       <td>0.015625</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.load('stage-2')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
classes = ['apple', 'banana', 'orange']

# %%
img = open_image('test/orange.jpeg')
img
# Out:
# Image (3, 1280, 960)

# %%
data2 = ImageDataBunch.single_from_classes(path, classes, ds_tfms=get_transforms(), size=224).normalize(imagenet_stats)

# %%
learn = cnn_learner(data2, models.resnet34)

# %%
learn.load('stage-2')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: data\fruits;
#
# Valid: LabelList (0 items)
# x: ImageList
#
# y: CategoryList
#
# Path: data\fruits;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category orange

# %% [markdown]
# # Yeah! Successfully predicted the fruit
